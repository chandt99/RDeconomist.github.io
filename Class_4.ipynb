# %% [markdown]
# <a href="https://colab.research.google.com/github/chandt99/RDeconomist.github.io/blob/main/Class_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/APINY',skiprows=4)

# %%
df.head(1)
# Out:
#   Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1961  1962  1963  1964  1965  ...      2012      2013      2014     2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ... -1.035375  6.429817 -0.020479  3.54363
#
#        2016      2017      2018    2019       2020  2021
# 0  2.116716  5.482371  1.267218 -2.0856 -22.318948   NaN
#
# [1 rows x 66 columns]

# %%
df2=df.drop(['Indicator Name','Indicator Code'],axis=1)

# %%
df3 = df2.set_index(['Country Name','Country Code']).stack().reset_index()

# %%
df4=df3.rename(columns={'level_2':'Year',0:'GDP growth (annual %)'})

# %%
df4
# Out:
#       Country Name Country Code  Year  GDP growth (annual %)
# 0            Aruba          ABW  1987              16.078431
# 1            Aruba          ABW  1988              18.648649
# 2            Aruba          ABW  1989              12.129841
# 3            Aruba          ABW  1990               3.961402
# 4            Aruba          ABW  1991               7.962872
# ...            ...          ...   ...                    ...
# 12418     Zimbabwe          ZWE  2017               4.709492
# 12419     Zimbabwe          ZWE  2018               4.824211
# 12420     Zimbabwe          ZWE  2019              -6.144236
# 12421     Zimbabwe          ZWE  2020              -6.248748
# 12422     Zimbabwe          ZWE  2021               5.849420
#
# [12423 rows x 4 columns]

# %%
df4.set_index('Country Code').to_csv('GDP1.csv')

# %%
df3.set_index(['Country Code','Country Name','level_2']).unstack()
# Out:
#                                                  0                      \
# level_2                                       1961      1962      1963
# Country Code Country Name
# ABW          Aruba                             NaN       NaN       NaN
# AFE          Africa Eastern and Southern  0.239594  7.980768  5.164334
# AFG          Afghanistan                       NaN       NaN       NaN
# AFW          Africa Western and Central   1.848752  3.770220  7.272440
# AGO          Angola                            NaN       NaN       NaN
# ...                                            ...       ...       ...
# XKX          Kosovo                            NaN       NaN       NaN
# YEM          Yemen, Rep.                       NaN       NaN       NaN
# ZAF          South Africa                 3.844734  6.177931  7.373709
# ZMB          Zambia                       1.361382 -2.490839  3.272393
# ZWE          Zimbabwe                     6.316157  1.434471  6.244345
#
# ...
