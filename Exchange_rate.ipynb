# %% [markdown]
# <a href="https://colab.research.google.com/github/chandt99/RDeconomist.github.io/blob/main/Exchange_rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/DEXUSUK (3)1.csv')
df.T.to_dict()
# Out:
# {0: {'DATE': '36526',
#   'Dollar-Pound ER': 1.6404,
#   'Date': '01/2000',
#   'Date2': '01/01/2000',
#   'Time': '2000-01-01'},
#  1: {'DATE': '02/2000',
#   'Dollar-Pound ER': 1.599985,
#   'Date': '02/2000',
#   'Date2': '01/02/2000',
#   'Time': '2000-02-01'},
#  2: {'DATE': '03/2000',
#   'Dollar-Pound ER': 1.5799,
#   'Date': '03/2000',
#   'Date2': '01/03/2000',
#   'Time': '2000-03-01'},
#  3: {'DATE': '04/2000',
#   'Dollar-Pound ER': 1.582345,
#   'Date': '04/2000',
#   'Date2': '01/04/2000',
#   'Time': '2000-04-01'},
#  4: {'DATE': '05/2000',
#   'Dollar-Pound ER': 1.508963636,
#   'Date': '05/2000',
#   'Date2': '01/05/2000',
#   'Time': '2000-05-01'},
#  5: {'DATE': '06/2000',
#   'Dollar-Pound ER': 1.509245455,
#   'Date': '06/2000',
#   'Date2': '01/06/2000',
#   'Time': '2000-06-01'},
#  6: {'DATE': '07/2000',
#   'Dollar-Pound ER': 1.507595,
#   'Date': '07/2000',
#   'Date2': '01/07/2000',
#   'Time': '2000-07-01'},
#  7: {'DATE': '08/2000',
# ...

# %%
exported_values= list(df.T.to_dict().values())

# %%
exported_values
# Out:
# [{'DATE': '36526',
#   'Dollar-Pound ER': 1.6404,
#   'Date': '01/2000',
#   'Date2': '01/01/2000',
#   'Time': '2000-01-01'},
#  {'DATE': '02/2000',
#   'Dollar-Pound ER': 1.599985,
#   'Date': '02/2000',
#   'Date2': '01/02/2000',
#   'Time': '2000-02-01'},
#  {'DATE': '03/2000',
#   'Dollar-Pound ER': 1.5799,
#   'Date': '03/2000',
#   'Date2': '01/03/2000',
#   'Time': '2000-03-01'},
#  {'DATE': '04/2000',
#   'Dollar-Pound ER': 1.582345,
#   'Date': '04/2000',
#   'Date2': '01/04/2000',
#   'Time': '2000-04-01'},
#  {'DATE': '05/2000',
#   'Dollar-Pound ER': 1.508963636,
#   'Date': '05/2000',
#   'Date2': '01/05/2000',
#   'Time': '2000-05-01'},
#  {'DATE': '06/2000',
#   'Dollar-Pound ER': 1.509245455,
#   'Date': '06/2000',
#   'Date2': '01/06/2000',
#   'Time': '2000-06-01'},
#  {'DATE': '07/2000',
#   'Dollar-Pound ER': 1.507595,
#   'Date': '07/2000',
#   'Date2': '01/07/2000',
#   'Time': '2000-07-01'},
#  {'DATE': '08/2000',
#   'Dollar-Pound ER': 1.488913043,
# ...

# %%
import json

# %%
open('ER.json','w').write(json.dumps(exported_values))
# Out:
# 31642
